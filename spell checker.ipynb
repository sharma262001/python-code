# %%
dictionary = ["receive","believe","friend","learning","machine","python","science","data","school","college","project",
              "analysis"]

# %%
print(dictionary)
['receive','believe','friend','learning','machine','python','science','data']
# Out:
# ['receive', 'believe', 'friend', 'learning', 'machine', 'python', 'science', 'data', 'school', 'college', 'project', 'analysis']
# ['receive',
#  'believe',
#  'friend',
#  'learning',
#  'machine',
#  'python',
#  'science',
#  'data']

# %%
def char_ngrams(word,n=2):
  word = word.lower()
  return [word[i:i+n] for i in range(len(word)-n+1)]

# %%
def jaccard_similarity(a,b):
  set1=set(a)
  set2=set(b)
  return len(set1 & set2)/len(set1|set2)

# %%
def improved_correction(word,dictionary,n=2):
  word_ngrams = char_ngrams(word,n)
  best_match = None
  best_score = 0

  for correct_word in dictionary:
    correct_ngrams = char_ngrams(correct_word,n)
    score = jaccard_similarity(word_ngrams,correct_ngrams)

    if score>best_score:
      best_score=score
      best_match = correct_word
  return best_match,best_score

# %%
wrong_words = ["recive","lrning","machine","science"]
for w in wrong_words:
  match,score = improved_correction(w,dictionary)
  print(f"{w}--->{match} (score: {score:.2f})")
# Out:
# recive--->receive (score: 0.57)
# lrning--->learning (score: 0.50)
# machine--->machine (score: 1.00)
# science--->science (score: 1.00)

# %%
import re

def preprocessing(word):
  word = word.lower()
  word =re.sub(r'[^a-z]',"",word)
  return word

# %%
preprocessing("hello@123!")
# Out:
# 'hello'

# %%
def improved_correction(word,dictionary,n=2):
  word = preprocessing(word)
  word_ngrams = char_ngrams(word,n)
  best_match = None
  best_score = 0

  for correct_word in dictionary:
    correct_ngrams = char_ngrams(correct_word,n)
    score = jaccard_similarity(word_ngrams,correct_ngrams)

    if score>best_score:
      best_score=score
      best_match = correct_word
  return best_match,best_score

# %%
test_word = ["receive","learning"]
for w in test_word:
  match,score = improved_correction(w,dictionary)
  print(f"{w}--->{match} (score: {score:.2f})")
# Out:
# receive--->receive (score: 1.00)
# adimandi--->friend (score: 0.10)

# %%
user_word = input("enter a word :")
match,score = improved_correction(user_word,dictionary)
print(f"suggested correction--->{match}(score :{score:.2f})")
# Out:
# enter a word :mashin
# suggested correction--->machine(score :0.38)
